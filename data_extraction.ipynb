# %%
import numpy
import pandas as pd
# from wordcloud import WordCloud
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
movies = pd.read_csv('/home/hitesh/Desktop/Data Science Project/Movie-Recommendation-System/Movielens dataset/movie.csv')
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
print("Dataframe Shape: ", movies.shape)
movies.dtypes
# Out:
# Dataframe Shape:  (27278, 3)
# movieId     int64
# title      object
# genres     object
# dtype: object

# %%
print(movies.isnull().sum())
# Out:
# movieId    0
# title      0
# genres     0
# dtype: int64

# %%
movies['genres'] = movies['genres'].str.split('|')
movies['genres'].head()
movies = movies.explode('genres')

# %%
movies2 = pd.read_csv('/home/hitesh/Desktop/Data Science Project/Movie-Recommendation-System/movie_metadata.csv')
movies2.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
## make a list of movie_title of movies2
movie_title = movies2['movie_title'].tolist()
movie_title = [x.replace('\xa0', '') for x in movie_title]
movie_title
# Out:
# ['Avatar',
#  "Pirates of the Caribbean: At World's End",
#  'Spectre',
#  'The Dark Knight Rises',
#  'Star Wars: Episode VII - The Force Awakens            ',
#  'John Carter',
#  'Spider-Man 3',
#  'Tangled',
#  'Avengers: Age of Ultron',
#  'Harry Potter and the Half-Blood Prince',
#  'Batman v Superman: Dawn of Justice',
#  'Superman Returns',
#  'Quantum of Solace',
#  "Pirates of the Caribbean: Dead Man's Chest",
#  'The Lone Ranger',
#  'Man of Steel',
#  'The Chronicles of Narnia: Prince Caspian',
#  'The Avengers',
#  'Pirates of the Caribbean: On Stranger Tides',
#  'Men in Black 3',
#  'The Hobbit: The Battle of the Five Armies',
#  'The Amazing Spider-Man',
#  'Robin Hood',
#  'The Hobbit: The Desolation of Smaug',
#  'The Golden Compass',
#  'King Kong',
#  'Titanic',
#  'Captain America: Civil War',
#  'Battleship',
#  'Jurassic World',
#  'Skyfall',
#  'Spider-Man 2',
#  'Iron Man 3',
#  'Alice in Wonderland',
#  'X-Men: The Last Stand',
#  'Monsters University',
# ...

# %%
## make a list of title of movies
title = movies['title'].tolist()
title = [x[:-7] for x in title]
title
# Out:
# ['Toy Story',
#  'Toy Story',
#  'Toy Story',
#  'Toy Story',
#  'Toy Story',
#  'Jumanji',
#  'Jumanji',
#  'Jumanji',
#  'Grumpier Old Men',
#  'Grumpier Old Men',
#  'Waiting to Exhale',
#  'Waiting to Exhale',
#  'Waiting to Exhale',
#  'Father of the Bride Part II',
#  'Heat',
#  'Heat',
#  'Heat',
#  'Sabrina',
#  'Sabrina',
#  'Tom and Huck',
#  'Tom and Huck',
#  'Sudden Death',
#  'GoldenEye',
#  'GoldenEye',
#  'GoldenEye',
#  'American President, The',
#  'American President, The',
#  'American President, The',
#  'Dracula: Dead and Loving It',
#  'Dracula: Dead and Loving It',
#  'Balto',
#  'Balto',
#  'Balto',
#  'Nixon',
#  'Cutthroat Island',
#  'Cutthroat Island',
#  'Cutthroat Island',
#  'Casino',
#  'Casino',
#  'Sense and Sensibility',
#  'Sense and Sensibility',
#  'Four Rooms',
#  'Ace Ventura: When Nature Calls',
#  'Money Train',
#  'Money Train',
#  'Money Train',
#  'Money Train',
#  'Money Train',
#  'Get Shorty',
#  'Get Shorty',
#  'Get Shorty',
# ...

# %%
## find intersection of two lists movie_title and title
intersection = list(set(movie_title) & set(title))

# %%
len(intersection)
# Out:
# 3077

# %%
import requests
from bs4 import BeautifulSoup
url = "https://www.imdb.com/title/tt0113497/"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36"}

# Send a GET request to the URL with headers
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
critic_reviews_link = soup.find('a', {'class': 'isReview', 'href': lambda x: x and 'externalreviews' in x})
num_critic_reviews = critic_reviews_link.find('span', {'class': 'score'}).text
print(num_critic_reviews)
# Out:
# 83

# %%
critic_reviews_link = soup.find('a', {'class': 'isReview', 'href': lambda x: x and 'externalreviews' in x})
num_critic_reviews = critic_reviews_link.find('span', {'class': 'score'}).text
print(num_critic_reviews)

user_reviews_link = soup.find('a', {'class': 'isReview', 'href': lambda x: x and 'reviews' in x})
num_user_reviews = user_reviews_link.find('span', {'class': 'score'}).text
print(num_user_reviews)
# Out:
# 83
# 320

# %%
# find the element that contains the score
score_elem = soup.find('div', {'class': 'sc-bde20123-2 gYgHoj'})

# extract the score from the element's text
score = score_elem.text.strip('').split('/')[0]

print(score)  # output: 8.3
# Out:
# 7.0

# %%
name_link = soup.find('a', {'class': 'ipc-metadata-list-item__list-content-item'})
name = name_link.text
print(name)
# Out:
# Joe Johnston

# %%
import re

cast_link = soup.find('a', {'class': 'ipc-metadata-list-item__label--link', 'href': re.compile('fullcredits')})
cast_container = cast_link.find_next('div', {'class': 'ipc-metadata-list-item__content-container'})
cast_names = [a.text for a in cast_container.find_all('a', {'class': 'ipc-metadata-list-item__list-content-item'})]

print(cast_names)
# Out:
# ['Jonathan Hensleigh', 'Greg Taylor', 'Jim Strain']

# %%
stars_section = soup.find('a', {'class': 'ipc-metadata-list-item__label--link', 'href': lambda x: x and '/fullcredits/cast' in x}).find_next('div', {'class': 'ipc-metadata-list-item__content-container'})
stars_links = stars_section.find_all('a', {'class': 'ipc-metadata-list-item__list-content-item--link'})
stars = [link.text for link in stars_links]
print(stars)
# Out:
# ['Robin Williams', 'Kirsten Dunst', 'Bonnie Hunt']

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === 'function'){ uet('bb', 'LoadTitle', {wb: 1}); }</script><script>window.addEventListener('load', (event) => {
#         if (typeof window.csa !== 'undefined' && typeof window.csa === 'function') {
#             var csaLatencyPlugin = window.csa('Content', {
#                 element: {
#                     slotId: 'LoadTitle',
#                     type: 'service-call'
#                 }
#             });
#             csaLatencyPlugin('mark', 'clickToBodyBegin', 1682272352378);
#         }
# ...

# %%
# save the soup in html format
soup_html = soup.prettify()
print(soup_html)
# Out:
# <!DOCTYPE html>
# <html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width" name="viewport"/>
#   <script>
#    if(typeof uet === 'function'){ uet('bb', 'LoadTitle', {wb: 1}); }
#   </script>
#   <script>
#    window.addEventListener('load', (event) => {
#         if (typeof window.csa !== 'undefined' && typeof window.csa === 'function') {
#             var csaLatencyPlugin = window.csa('Content', {
#                 element: {
#                     slotId: 'LoadTitle',
#                     type: 'service-call'
#                 }
#             });
#             csaLatencyPlugin('mark', 'clickToBodyBegin', 1682272352378);
#         }
#     })
#   </script>
#   <title>
#    Jumanji (1995) - IMDb
#   </title>
# ...

# %%
# <div class="sc-5f7fb5b4-1 bhuIgW" data-testid="hero-rating-bar__popularity__score">
# 362
# </div>
# getting the popularity score
score_elem = soup.find('div', {'class': 'sc-5f7fb5b4-1 bhuIgW'})
print(score_elem.text.strip(""))
print(type(score_elem.text.strip("")))
# Out:
# 362
# <class 'str'>

# %%
# <meta content="Jumanji: Directed by Joe Johnston. With Robin Williams, Jonathan Hyde, Kirsten Dunst, Bradley Pierce. When two kids find and play a magical board game, they release a man trapped in it for decades - and a host of dangers that can only be stopped by finishing the game." data-id="main" name="description"/>

summary = soup.find('meta', {'name': 'description'})['content']
print(summary)
# Out:
# Jumanji: Directed by Joe Johnston. With Robin Williams, Jonathan Hyde, Kirsten Dunst, Bradley Pierce. When two kids find and play a magical board game, they release a man trapped in it for decades - and a host of dangers that can only be stopped by finishing the game.

# %%
movie_lens_movie_data = pd.read_csv('Movielens dataset/link.csv')
movie_lens_movie_data.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
movie_lens_movie_data_modified = movie_lens_movie_data[:5].copy()
movie_lens_movie_data_modified
# create column for movie title, summary, score, cast, director, stars, popularity score, number of critic reviews, number of user reviews
new_col = ['summary', 'score', 'cast', 'director', 'stars', 'popularity_score', 'num_critic_reviews', 'num_user_reviews']
movie_lens_movie_data_modified = movie_lens_movie_data_modified.reindex(columns=movie_lens_movie_data_modified.columns.tolist() + new_col)
movie_lens_movie_data_modified
# Out:
#    movieId  imdbId   tmdbId  summary  score  cast  director  stars  \
# 0        1  114709    862.0      NaN    NaN   NaN       NaN    NaN
# 1        2  113497   8844.0      NaN    NaN   NaN       NaN    NaN
# 2        3  113228  15602.0      NaN    NaN   NaN       NaN    NaN
# 3        4  114885  31357.0      NaN    NaN   NaN       NaN    NaN
# 4        5  113041  11862.0      NaN    NaN   NaN       NaN    NaN
#
#    popularity_score  num_critic_reviews  num_user_reviews
# 0               NaN                 NaN               NaN
# 1               NaN                 NaN               NaN
# 2               NaN                 NaN               NaN
# 3               NaN                 NaN               NaN
# 4               NaN                 NaN               NaN

# %%
movie_lens_movie_data_modified.loc[movie_lens_movie_data_modified['imdbId'] == 114709, 'num_user_reviews'] = int(798)

# %%
movie_lens_movie_data_modified
# Out:
#    movieId  imdbId   tmdbId  movie_title  summary  score  cast  director  \
# 0        1  114709    862.0          NaN      NaN    NaN   NaN       NaN
# 1        2  113497   8844.0          NaN      NaN    NaN   NaN       NaN
# 2        3  113228  15602.0          NaN      NaN    NaN   NaN       NaN
# 3        4  114885  31357.0          NaN      NaN    NaN   NaN       NaN
# 4        5  113041  11862.0          NaN      NaN    NaN   NaN       NaN
#
#    stars  popularity_score  num_critic_reviews  num_user_reviews
# 0    NaN               NaN                 NaN             798.0
# 1    NaN               NaN                 NaN               NaN
# 2    NaN               NaN                 NaN               NaN
# 3    NaN               NaN                 NaN               NaN
# 4    NaN               NaN                 NaN               NaN

# %%
# writing the function for scraping all the above information

def get_movie_data(movie_id):
    imdb_url = "https://www.imdb.com/title/tt" + str(movie_id).zfill(7) + "/"
    headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36"}

    # Send a GET request to the URL with headers
    response = requests.get(imdb_url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # total user reviews
    user_reviews_link = soup.find('a', {'class': 'isReview', 'href': lambda x: x and 'reviews' in x})
    num_user_reviews = user_reviews_link.find('span', {'class': 'score'}).text
    movie_lens_movie_data_modified.loc[movie_lens_movie_data_modified['imdbId'] == movie_id, 'num_user_reviews'] = int(num_user_reviews)
    
    # num of critic reviews
    critic_reviews_link = soup.find('a', {'class': 'isReview', 'href': lambda x: x and 'externalreviews' in x})
    num_critic_reviews = critic_reviews_link.find('span', {'class': 'score'}).text
    movie_lens_movie_data_modified.loc[movie_lens_movie_data_modified['imdbId'] == movie_id, 'num_critic_reviews'] = int(num_critic_reviews)
    # print(num_critic_reviews)
    
    # popularity score
    popularity_score = soup.find('div', {'class': 'sc-5f7fb5b4-1 bhuIgW'}).text.strip("")
    movie_lens_movie_data_modified.loc[movie_lens_movie_data_modified['imdbId'] == movie_id, 'popularity_score'] = float(popularity_score)
    
    # ratings
    ratings_score = soup.find('div', {'class': 'sc-bde20123-2 gYgHoj'}).text.strip('').split('/')[0]
    movie_lens_movie_data_modified.loc[movie_lens_movie_data_modified['imdbId'] == movie_id, 'score'] = float(ratings_score)
    
    # Director
    director_name = soup.find('a', {'class': 'ipc-metadata-list-item__list-content-item'}).text
    movie_lens_movie_data_modified.loc[movie_lens_movie_data_modified['imdbId'] == movie_id, 'director'] = director_name

    
    # Writers return list
    writers_link = soup.find('a', {'class': 'ipc-metadata-list-item__label--link', 'href': re.compile('fullcredits')})
    writers_container = writers_link.find_next('div', {'class': 'ipc-metadata-list-item__content-container'})
    writers_names = [a.text for a in writers_container.find_all('a', {'class': 'ipc-metadata-list-item__list-content-item'})]
    movie_lens_movie_data_modified.loc[movie_lens_movie_data_modified['imdbId'] == movie_id, 'cast'] = "|".join(writers_names)

    # stars return list
    stars_section = soup.find('a', {'class': 'ipc-metadata-list-item__label--link', 'href': lambda x: x and '/fullcredits/cast' in x}).find_next('div', {'class': 'ipc-metadata-list-item__content-container'})
    stars_links = stars_section.find_all('a', {'class': 'ipc-metadata-list-item__list-content-item--link'})
    stars = [link.text for link in stars_links]
    movie_lens_movie_data_modified.loc[movie_lens_movie_data_modified['imdbId'] == movie_id, 'stars'] = "|".join(stars)
    # print(stars)
    
    # movie information
    movie_info = soup.find('meta', {'name': 'description'})['content']
    movie_lens_movie_data_modified.loc[movie_lens_movie_data_modified['imdbId'] == movie_id, 'summary'] = movie_info
    

    print(f"Num of user reviews: {num_user_reviews}\nNum of critic reviews: {num_critic_reviews}\nPopularity score: {popularity_score}\nRatings: {ratings_score}\nDirector: {director_name}\nWriters: {writers_names}\nStars: {stars}\nMovie info: {movie_info}")
    movie_lens_movie_data_modified.to_csv('movie_data.csv', index=False)
    
    return None

get_movie_data(114709)
# Out:
# Num of user reviews: 762
# Num of critic reviews: 164
# Popularity score: 619
# Ratings: 8.3
# Director: John Lasseter
# Writers: ['John Lasseter', 'Pete Docter', 'Andrew Stanton']
# Stars: ['Tom Hanks', 'Tim Allen', 'Don Rickles']
# Movie info: Toy Story: Directed by John Lasseter. With Tom Hanks, Tim Allen, Don Rickles, Jim Varney. A cowboy doll is profoundly threatened and jealous when a new spaceman action figure supplants him as top toy in a boy's bedroom.

# %%
movie_lens_movie_data_modified
# Out:
#    movieId  imdbId   tmdbId  \
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0
#
#                                              summary  score  \
# 0  Toy Story: Directed by John Lasseter. With Tom...    8.3
# 1                                                NaN    NaN
# 2                                                NaN    NaN
# 3                                                NaN    NaN
# 4                                                NaN    NaN
#
#                                        cast       director  \
# 0  John Lasseter|Pete Docter|Andrew Stanton  John Lasseter
# 1                                       NaN            NaN
# 2                                       NaN            NaN
# 3                                       NaN            NaN
# 4                                       NaN            NaN
#
# ...
